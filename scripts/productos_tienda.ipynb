# %%
import sys, importlib
sys.path.append(r"C:/Users/alber/OneDrive/Desktop/Proyectos/Baratazo")  # usa r"..." en Windows
import os
import re
import math
from pathlib import Path

import pandas as pd
from sqlalchemy import create_engine, text
from sqlalchemy.exc import IntegrityError

# Scrapers
from mercadona import scrape_mercadona
from guardar_mercadona import reload_mercadona

from bonpreu import scrape_bonpreu
from consum import scrape_consum

# %%
def _num_es_txt(s: str):
    if not s:
        return None
    s = str(s).replace("\xa0", " ").strip()
    m = re.search(r"(\d{1,3}(?:\.\d{3})*(?:,\d+)|\d+,\d+|\d+(?:\.\d+)?)", s)
    if not m:
        return None
    t = m.group(1)
    if "," in t and "." in t:
        t = t.replace(".", "").replace(",", ".")
    elif "," in t:
        t = t.replace(",", ".")
    try:
        return float(t)
    except:
        return None


def _ppu_simple(ppu_text):
    """
    Extrae el número que aparece antes del símbolo € en price_per_unit_text.
    Ejemplos:
      '(1,19 € per article)' -> 1.19
      '0,75 € / 100 g' -> 0.75
      '2.50 €/L' -> 2.50
    Devuelve float o None.
    """
    if not ppu_text:
        return None
    s = str(ppu_text)
    m = re.search(r"([\d.,]+)\s*€", s)
    if not m:
        return None
    t = m.group(1).replace(".", "").replace(",", ".")
    try:
        return float(t)
    except:
        return None


def _extract_qty(text: str):
    """
    Devuelve (total_kg, total_l) a partir de cadenas como:
    'Garrafa 5 L', 'Botella 1,5 L', '500 g', 'Pack 6 x 330 ml', '2x1 L', '6×33 cl'...
    """
    if not text:
        return (None, None)
    t = text.lower().replace(",", ".")
    # pack: NxY(unidad)
    m = re.search(r"(\d+)\s*[x×]\s*(\d+(?:\.\d+)?)\s*(kg|g|l|ml|cl)", t)
    if m:
        n = int(m.group(1))
        q = float(m.group(2))
        u = m.group(3)
        if u == "kg":
            return (n * q, None)
        if u == "g":
            return (n * (q / 1000.0), None)
        if u == "l":
            return (None, n * q)
        if u == "ml":
            return (None, n * (q / 1000.0))
        if u == "cl":
            return (None, n * (q / 100.0))
    # simple: Y(unidad)
    m = re.search(r"(\d+(?:\.\d+)?)\s*(kg|g|l|ml|cl)", t)
    if m:
        q = float(m.group(1))
        u = m.group(2)
        if u == "kg":
            return (q, None)
        if u == "g":
            return (q / 1000.0, None)
        if u == "l":
            return (None, q)
        if u == "ml":
            return (None, q / 1000.0)
        if u == "cl":
            return (None, q / 100.0)
    return (None, None)


def _compute_row(r: pd.Series):
    ppt = (r.get("price_per_unit_text") or "").lower()
    price = r.get("price")
    ppk = ppl = None

    # 1) Si el propio sitio ya da €/kg o €/l, úsalo
    if "€/kg" in ppt or "€/ kilo" in ppt:
        ppk = _num_es_txt(ppt)
    if "€/l" in ppt or "€/litro" in ppt:
        ppl = _num_es_txt(ppt)

    # 2) Si no viene, infiere desde el formato/nombre
    if (ppk is None and ppl is None) and price is not None and not (isinstance(price, float) and math.isnan(price)):
        txt = f"{r.get('format_text','')} {r.get('name','')}"
        total_kg, total_l = _extract_qty(txt)
        if total_kg and total_kg > 0:
            ppk = float(price) / total_kg
        if total_l and total_l > 0:
            ppl = float(price) / total_l

    # Redondeos
    if ppk is not None:
        ppk = round(ppk, 4)
    if ppl is not None:
        ppl = round(ppl, 4)
    return pd.Series({"price_per_kg": ppk, "price_per_l": ppl})

_rx_ppu = re.compile(r"([\d.,]+)\s*€\s*/\s*([^\s]+(?:\s*[^\s]+)?)", re.I)

def _to_float(s):
    try:
        return float(str(s).replace(".", "").replace(",", "."))
    except Exception:
        return None

def _ppu_to_base(ppu_text: str, fallback_unit_price: float) -> float:
    """
    Convierte ppu_text a €/kg o €/l si es posible.
    Si es por unidad/metro/etc., devuelve price_unit (fallback).
    """
    if not isinstance(ppu_text, str) or not ppu_text.strip():
        return float(fallback_unit_price)

    m = _rx_ppu.search(ppu_text.replace("\xa0", " "))
    if not m:
        return float(fallback_unit_price)

    val = _to_float(m.group(1))
    if val is None:
        return float(fallback_unit_price)

    unit = m.group(2).strip().lower()
    unit = unit.replace(" ", "")  # "1 kg" -> "1kg"

    # Normaliza unidades típicas
    if unit in ("kg", "1kg"):
        return float(val)
    if unit in ("l", "1l", "lt", "litro", "litros"):
        return float(val)

    # gramos y mililitros
    if unit in ("g", "1g"):
        return float(val) * 1000.0        # €/g -> €/kg
    if unit in ("100g", "100gr", "100gramos"):
        return float(val) * 10.0          # €/100g -> €/kg
    if unit in ("ml", "1ml"):
        return float(val) * 1000.0        # €/ml -> €/l
    if unit in ("100ml",):
        return float(val) * 10.0          # €/100ml -> €/l

    # por unidad / metro / pack u otras: no se puede pasar a kg/l
    if unit in ("u", "ud", "unidad", "1u", "1ud", "1unidad", "m", "1m"):
        return float(fallback_unit_price)

    # Cualquier otra unidad rara: usa fallback
    return float(fallback_unit_price)

# %% [markdown]
# ### MERCADONA

# %%
df_mercadona = scrape_mercadona(
    start_category_url="https://tienda.mercadona.es/categories/112",
    cp="08203",
    headless=True,
    load_images=True,   # si te importa la columna img_url; pon False para ir aún más rápido
    pause=0.10
)
# Out:
# → Abriendo https://tienda.mercadona.es/categories/112
# ✓ CP fijado: 08203
# → Secciones detectadas: 26
#
# === SECCIÓN 1/26: Aceite, especias y salsas ===
#   • Subcategorías: 4
#     → 1/4  Aceite, vinagre y sal (id=112)  …click
#       ✔ 37 productos en 5.9s
#     → 2/4  Especias (id=115)  …click
#       ✔ 51 productos en 7.6s
#     → 3/4  Mayonesa, ketchup y mostaza (id=116)  …click
#       ✔ 19 productos en 3.0s
#     → 4/4  Otras salsas (id=117)  …click
#       ✔ 41 productos en 5.9s
#
# === SECCIÓN 2/26: Agua y refrescos ===
#   • Subcategorías: 6
#     → 1/6  Agua (id=156)  …click
#       ✔ 50 productos en 7.4s
#     → 2/6  Isotónico y energético (id=163)  …click
#       ✔ 39 productos en 5.8s
#     → 3/6  Refresco de cola (id=158)  …click
#       ✔ 31 productos en 8.1s
#     → 4/6  Refresco de naranja y de limón (id=159)  …click
#       ✔ 36 productos en 6.5s
#     → 5/6  Tónica y bitter (id=161)  …click
#       ✔ 11 productos en 2.5s
#     → 6/6  Refresco de té y sin gas (id=162)  …click
#       ✔ 29 productos en 5.0s
#
# === SECCIÓN 3/26: Aperitivos ===
#   • Subcategorías: 3
#     → 1/3  Aceitunas y encurtidos (id=135)  …click
#       ✔ 42 productos en 6.3s
#     → 2/3  Frutos secos y fruta desecada (id=133)  …click
#       ✔ 65 productos en 9.0s
#     → 3/3  Patatas fritas y snacks (id=132)  …click
#       ✔ 45 productos en 7.1s
#
# === SECCIÓN 4/26: Arroz, legumbres y pasta ===
#   • Subcategorías: 3
#     → 1/3  Arroz (id=118)  …click
#       ✔ 15 productos en 2.8s
#     → 2/3  Legumbres (id=121)  …click
#       ✔ 21 productos en 3.7s
#     → 3/3  Pasta y fideos (id=120)  …click
#       ✔ 56 productos en 9.3s
#
# === SECCIÓN 5/26: Azúcar, caramelos y chocolate ===
#   • Subcategorías: 6
#     → 1/6  Azúcar y edulcorante (id=89)  …click
#       ✔ 15 productos en 2.8s
#     → 2/6  Chicles y caramelos (id=95)  …click
#       ✔ 29 productos en 4.4s
#     → 3/6  Chocolate (id=92)  …click
#       ✔ 76 productos en 10.4s
#     → 4/6  Golosinas (id=97)  …click
#       ✔ 19 productos en 3.5s
#     → 5/6  Mermelada y miel (id=90)  …click
#       ✔ 17 productos en 3.1s
#     → 6/6  Turrones (id=833)  …click
#       ✔ 25 productos en 4.2s
#
# === SECCIÓN 6/26: Bebé ===
#   • Subcategorías: 4
#     → 1/4  Alimentación infantil (id=216)  …click
#       ✔ 39 productos en 5.7s
#     → 2/4  Biberón y chupete (id=219)  …click
#       ✔ 7 productos en 2.5s
#     → 3/4  Higiene y cuidado (id=218)  …click
#       ✔ 12 productos en 2.1s
#     → 4/4  Toallitas y pañales (id=217)  …click
#       ✔ 24 productos en 3.7s
#
# === SECCIÓN 7/26: Bodega ===
#   • Subcategorías: 9
#     → 1/9  Cerveza (id=164)  …click
#       ✔ 70 productos en 10.3s
#     → 2/9  Cerveza sin alcohol (id=166)  …click
#       ✔ 16 productos en 3.7s
#     → 3/9  Licores (id=181)  …click
#       ✔ 45 productos en 6.6s
#     → 4/9  Sidra y cava (id=174)  …click
#       ✔ 16 productos en 2.9s
#     → 5/9  Tinto de verano y sangría (id=168)  …click
#       ✔ 5 productos en 1.6s
#     → 6/9  Vino blanco (id=170)  …click
#       ✔ 28 productos en 5.0s
#     → 7/9  Vino lambrusco y espumoso (id=173)  …click
#       ✔ 6 productos en 2.1s
#     → 8/9  Vino rosado (id=171)  …click
#       ✔ 5 productos en 1.5s
#     → 9/9  Vino tinto (id=169)  …click
#       ✔ 31 productos en 5.0s
#
# === SECCIÓN 8/26: Cacao, café e infusiones ===
#   • Subcategorías: 5
#     → 1/5  Cacao soluble y chocolate a la taza (id=86)  …click
#       ✔ 14 productos en 2.9s
#     → 2/5  Café cápsula y monodosis (id=81)  …click
#       ✔ 31 productos en 4.5s
#     → 3/5  Café molido y en grano (id=83)  …click
#       ✔ 18 productos en 2.9s
#     → 4/5  Café soluble y otras bebidas (id=84)  …click
#       ✔ 20 productos en 3.4s
#     → 5/5  Té e infusiones (id=88)  …click
#       ✔ 28 productos en 4.3s
#
# === SECCIÓN 9/26: Carne ===
#   • Subcategorías: 9
#     → 1/9  Arreglos (id=46)  …click
#       ✔ 13 productos en 2.8s
#     → 2/9  Aves y pollo (id=38)  …click
#       ✔ 51 productos en 7.7s
#     → 3/9  Carne congelada (id=47)  …click
#       ✔ 14 productos en 2.7s
#     → 4/9  Cerdo (id=37)  …click
#       ✔ 40 productos en 5.8s
#     → 5/9  Conejo y cordero (id=42)  …click
#       ✔ 7 productos en 2.1s
#     → 6/9  Embutido (id=43)  …click
#       ✔ 12 productos en 2.0s
#     → 7/9  Hamburguesas y picadas (id=44)  …click
#       ✔ 26 productos en 4.2s
#     → 8/9  Vacuno (id=40)  …click
#       ✔ 11 productos en 2.1s
#     → 9/9  Empanados y elaborados (id=45)  …click
#       ✔ 29 productos en 4.7s
#
# === SECCIÓN 10/26: Cereales y galletas ===
#   • Subcategorías: 3
#     → 1/3  Cereales (id=78)  …click
#       ✔ 41 productos en 6.2s
#     → 2/3  Galletas (id=80)  …click
#       ✔ 64 productos en 9.2s
#     → 3/3  Tortitas (id=79)  …click
#       ✔ 8 productos en 1.6s
#
# === SECCIÓN 11/26: Charcutería y quesos ===
#   • Subcategorías: 9
#     → 1/9  Aves y jamón cocido (id=48)  …click
#       ✔ 35 productos en 5.4s
#     → 2/9  Bacón y salchichas (id=52)  …click
#       ✔ 22 productos en 3.7s
#     → 3/9  Chopped y mortadela (id=49)  …click
#       ✔ 11 productos en 2.1s
#     → 4/9  Embutido curado (id=51)  …click
#       ✔ 55 productos en 8.1s
#     → 5/9  Jamón serrano (id=50)  …click
#       ✔ 26 productos en 4.4s
#     → 6/9  Paté y sobrasada (id=58)  …click
#       ✔ 24 productos en 3.7s
#     → 7/9  Queso curado, semicurado y tierno (id=54)  …click
#       ✔ 47 productos en 6.9s
#     → 8/9  Queso lonchas, rallado y en porciones (id=56)  …click
#       ✔ 28 productos en 4.1s
#     → 9/9  Queso untable y fresco (id=53)  …click
#       ✔ 44 productos en 6.5s
#
# === SECCIÓN 12/26: Congelados ===
#   • Subcategorías: 10
#     → 1/10  Arroz y pasta (id=147)  …click
#       ✔ 15 productos en 2.8s
#     → 2/10  Carne (id=148)  …click
#       ✔ 13 productos en 2.5s
#     → 3/10  Helados (id=154)  …click
#       ✔ 38 productos en 6.0s
#     → 4/10  Hielo (id=155)  …click
#       ✔ 3 productos en 1.3s
#     → 5/10  Marisco (id=150)  …click
#       ✔ 16 productos en 2.9s
#     → 6/10  Pescado (id=149)  …click
#       ✔ 34 productos en 5.4s
#     → 7/10  Pizzas (id=151)  …click
#       ✔ 13 productos en 2.5s
#     → 8/10  Rebozados (id=884)  …click
#       ✔ 28 productos en 4.4s
#     → 9/10  Tartas y churros (id=152)  …click
#       ✔ 19 productos en 3.1s
#     → 10/10  Verdura (id=145)  …click
#       ✔ 54 productos en 7.8s
#
# === SECCIÓN 13/26: Conservas, caldos y cremas ===
#   • Subcategorías: 6
#     → 1/6  Atún y otras conservas de pescado (id=122)  …click
#       ✔ 29 productos en 4.5s
#     → 2/6  Berberechos y mejillones (id=123)  …click
#       ✔ 13 productos en 2.7s
#     → 3/6  Conservas de verdura y frutas (id=127)  …click
#       ✔ 45 productos en 6.4s
#     → 4/6  Gazpacho y cremas (id=130)  …click
#       ✔ 20 productos en 3.3s
#     → 5/6  Sopa y caldo (id=129)  …click
#       ✔ 22 productos en 3.8s
#     → 6/6  Tomate (id=126)  …click
#       ✔ 17 productos en 2.8s
#
# === SECCIÓN 14/26: Cuidado del cabello ===
#   • Subcategorías: 4
#     → 1/4  Acondicionador y mascarilla (id=201)  …click
#       ✔ 33 productos en 5.2s
#     → 2/4  Champú (id=199)  …click
#       ✔ 31 productos en 4.7s
#     → 3/4  Coloración cabello (id=203)  …click
#       ✔ 93 productos en 12.6s
#     → 4/4  Fijación cabello (id=202)  …click
#       ✔ 26 productos en 4.3s
#
# === SECCIÓN 15/26: Cuidado facial y corporal ===
#   • Subcategorías: 11
#     → 1/11  Afeitado y cuidado para hombre (id=192)  …click
#       ✔ 32 productos en 4.9s
#     → 2/11  Cuidado corporal (id=189)  …click
#       ✔ 46 productos en 7.7s
#     → 3/11  Cuidado e higiene facial (id=185)  …click
#       ✔ 59 productos en 9.7s
#     → 4/11  Depilación (id=191)  …click
#       ✔ 20 productos en 3.4s
#     → 5/11  Desodorante (id=188)  …click
#       ✔ 41 productos en 7.0s
#     → 6/11  Gel y jabón de manos (id=187)  …click
#       ✔ 44 productos en 6.2s
#     → 7/11  Higiene bucal (id=186)  …click
#       ✔ 51 productos en 7.5s
#     → 8/11  Higiene íntima (id=190)  …click
#       ✔ 61 productos en 8.6s
#     → 9/11  Manicura y pedicura (id=194)  …click
#       ✔ 33 productos en 5.7s
#     → 10/11  Perfume y colonia (id=196)  …click
#       ✔ 94 productos en 13.2s
#     → 11/11  Protector solar y aftersun (id=198)  …click
#       ✔ 4 productos en 1.0s
#
# === SECCIÓN 16/26: Fitoterapia y parafarmacia ===
#   • Subcategorías: 2
#     → 1/2  Fitoterapia (id=213)  …click
#       ✔ 25 productos en 3.7s
#     → 2/2  Parafarmacia (id=214)  …click
#       ✔ 32 productos en 5.4s
#
# === SECCIÓN 17/26: Fruta y verdura ===
#   • Subcategorías: 3
#     → 1/3  Fruta (id=27)  …click
#       ✔ 50 productos en 7.3s
#     → 2/3  Lechuga y ensalada preparada (id=28)  …click
#       ✔ 32 productos en 4.9s
#     → 3/3  Verdura (id=29)  …click
#       ✔ 88 productos en 12.1s
#
# === SECCIÓN 18/26: Huevos, leche y mantequilla ===
#   • Subcategorías: 3
#     → 1/3  Huevos (id=77)  …click
#       ✔ 11 productos en 2.4s
#     → 2/3  Leche y bebidas vegetales (id=72)  …click
#       ✔ 120 productos en 16.2s
#     → 3/3  Mantequilla y margarina (id=75)  …click
#       ✔ 25 productos en 4.0s
#
# === SECCIÓN 19/26: Limpieza y hogar ===
#   • Subcategorías: 14
#     → 1/14  Detergente y suavizante ropa (id=226)  …click
#       ✔ 40 productos en 6.4s
#     → 2/14  Estropajo, bayeta y guantes (id=237)  …click
#       ✔ 28 productos en 4.1s
#     → 3/14  Insecticida y ambientador (id=241)  …click
#       ✔ 67 productos en 9.7s
#     → 4/14  Lejía y líquidos fuertes (id=234)  …click
#       ✔ 16 productos en 2.9s
#     → 5/14  Limpiacristales (id=235)  …click
#       ✔ 7 productos en 2.0s
#     → 6/14  Limpiahogar y friegasuelos (id=233)  …click
#       ✔ 19 productos en 3.4s
#     → 7/14  Limpieza baño y WC (id=231)  …click
#       ✔ 16 productos en 2.7s
#     → 8/14  Limpieza cocina (id=230)  …click
#       ✔ 10 productos en 2.2s
#     → 9/14  Limpieza muebles y multiusos (id=232)  …click
#       ✔ 16 productos en 2.9s
#     → 10/14  Limpieza vajilla (id=229)  …click
#       ✔ 20 productos en 3.5s
#     → 11/14  Menaje y conservación de alimentos (id=243)  …click
#       ✔ 45 productos en 6.4s
#     → 12/14  Papel higiénico y celulosa (id=238)  …click
#       ✔ 19 productos en 3.1s
#     → 13/14  Pilas y bolsas de basura (id=239)  …click
#       ✔ 12 productos en 2.3s
#     → 14/14  Utensilios de limpieza y calzado (id=244)  …click
#       ✔ 31 productos en 4.6s
#
# === SECCIÓN 20/26: Maquillaje ===
#   • Subcategorías: 5
#     → 1/5  Bases de maquillaje y corrector (id=206)  …click
#       ✔ 52 productos en 7.8s
#     → 2/5  Colorete y polvos (id=207)  …click
#       ✔ 27 productos en 4.1s
#     → 3/5  Labios (id=208)  …click
#       ✔ 67 productos en 10.3s
#     → 4/5  Ojos (id=210)  …click
#       ✔ 57 productos en 8.8s
#     → 5/5  Pinceles y brochas (id=212)  …click
#       ✔ 7 productos en 1.6s
#
# === SECCIÓN 21/26: Marisco y pescado ===
#   • Subcategorías: 4
#     → 1/4  Marisco (id=32)  …click
#       ✔ 35 productos en 5.6s
#     → 2/4  Pescado congelado (id=34)  …click
#       ✔ 49 productos en 6.9s
#     → 3/4  Pescado fresco (id=31)  …click
#       ✔ 62 productos en 8.6s
#     → 4/4  Salazones y ahumados (id=36)  …click
#       ✔ 18 productos en 3.0s
#
# === SECCIÓN 22/26: Mascotas ===
#   • Subcategorías: 3
#     → 1/3  Gato (id=222)  …click
#       ✔ 36 productos en 6.0s
#     → 2/3  Perro (id=221)  …click
#       ✔ 44 productos en 6.3s
#     → 3/3  Otros (id=225)  …click
#       ✔ 9 productos en 1.8s
#
# === SECCIÓN 23/26: Panadería y pastelería ===
#   • Subcategorías: 9
#     → 1/9  Bollería de horno (id=65)  …click
#       ✔ 33 productos en 4.8s
#     → 2/9  Bollería envasada (id=66)  …click
#       ✔ 62 productos en 9.4s
#     → 3/9  Harina y preparado repostería (id=69)  …click
#       ✔ 41 productos en 5.9s
#     → 4/9  Pan de horno (id=59)  …click
#       ✔ 38 productos en 6.2s
#     → 5/9  Pan de molde y otras especialidades (id=60)  …click
#       ✔ 36 productos en 5.1s
#     → 6/9  Pan tostado y rallado (id=62)  …click
#       ✔ 26 productos en 3.9s
#     → 7/9  Picos, rosquilletas y picatostes (id=64)  …click
#       ✔ 20 productos en 3.1s
#     → 8/9  Tartas y pasteles (id=68)  …click
#       ✔ 16 productos en 2.7s
#     → 9/9  Velas y decoración (id=71)  …click
#       ✔ 19 productos en 3.5s
#
# === SECCIÓN 24/26: Pizzas y platos preparados ===
#   • Subcategorías: 4
#     → 1/4  Listo para Comer (id=897)  …click
#       ✔ 20 productos en 3.2s
#     → 2/4  Pizzas (id=138)  …click
#       ✔ 45 productos en 6.8s
#     → 3/4  Platos preparados calientes (id=140)  …click
#       ✔ 66 productos en 9.3s
#     → 4/4  Platos preparados fríos (id=142)  …click
#       ✔ 25 productos en 3.8s
#
# === SECCIÓN 25/26: Postres y yogures ===
#   • Subcategorías: 9
#     → 1/9  Bífidus (id=105)  …click
#       ✔ 17 productos en 3.0s
#     → 2/9  Flan y natillas (id=110)  …click
#       ✔ 14 productos en 3.5s
#     → 3/9  Gelatina y otros postres (id=111)  …click
#       ✔ 25 productos en 4.2s
#     → 4/9  Postres de soja (id=106)  …click
#       ✔ 8 productos en 1.8s
#     → 5/9  Yogures desnatados (id=103)  …click
#       ✔ 14 productos en 2.7s
#     → 6/9  Yogures griegos (id=109)  …click
#       ✔ 10 productos en 2.3s
#     → 7/9  Yogures líquidos (id=108)  …click
#       ✔ 30 productos en 4.8s
#     → 8/9  Yogures naturales y sabores (id=104)  …click
#       ✔ 21 productos en 3.3s
#     → 9/9  Yogures y postres infantiles (id=107)  …click
#       ✔ 8 productos en 1.8s
#
# === SECCIÓN 26/26: Zumos ===
#   • Subcategorías: 4
#     → 1/4  Fruta variada (id=99)  …click
#       ✔ 22 productos en 3.4s
#     → 2/4  Melocotón y piña (id=100)  …click
#       ✔ 12 productos en 2.9s
#     → 3/4  Naranja (id=143)  …click
#       ✔ 13 productos en 2.5s
#     → 4/4  Tomate y otros sabores (id=98)  …click
#       ✔ 8 productos en 1.9s
#
# ✅ TOTAL productos: 4680

# %%
df_mercadona["store"] = "Mercadona"
df_mercadona["price_per_kg_or_l_or_unit"] = df_mercadona["price_kg"].fillna(df_mercadona["price_l"]).fillna(df_mercadona["price_unit_count"])

# %%
reload_mercadona(df_mercadona)
# Out:
# ✅ Mercadona: productos_insertados=4429, categorias_nuevas=152, enlaces_creados=4680

# %% [markdown]
# ### BONPREU

# %%
df_bonpreu = scrape_bonpreu(headless=True)
# Out:
# ✅ Cookies aceptadas
# ✅ Cookies aceptadas
# 🧮 2119 productos extraídos de https://www.compraonline.bonpreuesclat.cat/categories/frescos/c95cfbf2-501d-433f-bae3-10fcef330b11?sortBy=favorite
# ✅ Cookies aceptadas
# 🧮 4172 productos extraídos de https://www.compraonline.bonpreuesclat.cat/categories/alimentaci%C3%B3/c49d1ef2-bf51-44a7-b631-4a35474a21ac?sortBy=favorite
# ✅ Cookies aceptadas
# 🧮 1944 productos extraídos de https://www.compraonline.bonpreuesclat.cat/categories/begudes/3660db45-baa3-4c9f-9bb1-7cba443b3c9f?sortBy=favorite
# 🧮 568 productos extraídos de https://www.compraonline.bonpreuesclat.cat/categories/congelats/79a52e84-e446-47fb-b032-dfa044ecb779?sortBy=favorite
# ✅ Cookies aceptadas
# 🧮 819 productos extraídos de https://www.compraonline.bonpreuesclat.cat/categories/l%C3%A0ctics-i-ous/8e6bb6f8-67ac-4a57-8260-c861830774f0?sortBy=favorite
# ✅ Cookies aceptadas
# 🧮 2348 productos extraídos de https://www.compraonline.bonpreuesclat.cat/categories/cura-personal/b2c9fc2f-ddb1-40ff-8277-f7b102107f1e?sortBy=favorite
# ✅ Cookies aceptadas
# 🧮 823 productos extraídos de https://www.compraonline.bonpreuesclat.cat/categories/neteja-de-la-llar/5b850132-84f1-4f40-9c14-f51fb3f24ac7?sortBy=favorite
# ✅ Cookies aceptadas
# 🧮 3656 productos extraídos de https://www.compraonline.bonpreuesclat.cat/categories/per-la-llar/6ea50412-555a-4d5a-86bc-ee5bb1961e44?sortBy=favorite
# ✅ Cookies aceptadas
# 🧮 2026 productos extraídos de https://www.compraonline.bonpreuesclat.cat/categories/nadal/71cd2d9f-7b04-4b06-b973-ecddfbc7ad55?sortBy=favorite
# ✅ Cookies aceptadas
# 🧮 793 productos extraídos de https://www.compraonline.bonpreuesclat.cat/categories/espai-mascotes/503fab97-1ab4-48c4-b115-134784f0a5d6?sortBy=favorite
# ✅ Cookies aceptadas
# 🧮 318 productos extraídos de https://www.compraonline.bonpreuesclat.cat/categories/nadons/89c192be-c60e-4c2b-90c2-3e94f3eb525f?sortBy=favorite
# ✅ Cookies aceptadas
# 🧮 1499 productos extraídos de https://www.compraonline.bonpreuesclat.cat/categories/parafarm%C3%A0cia/402b37ee-e28d-42d0-825d-395a4d8d412e?sortBy=favorite
# ✅ Cookies aceptadas
# 🧮 1202 productos extraídos de https://www.compraonline.bonpreuesclat.cat/categories/dietes-intoler%C3%A0ncies-i-estils-de-vida/85881db4-b23e-4e02-8e2e-9dae38543e40?sortBy=favorite
# ✅ Cookies aceptadas
# 🧮 1215 productos extraídos de https://www.compraonline.bonpreuesclat.cat/categories/productes-km0/a37a22b7-473b-4b45-9bf7-81962153dde0?sortBy=favorite
# ✅ Cookies aceptadas
# 🧮 154 productos extraídos de https://www.compraonline.bonpreuesclat.cat/categories/castanyada/3240c485-8e0a-402d-86d2-00a1a4f1fdc8?sortBy=favorite
# ✅ Cookies aceptadas
# 🧮 975 productos extraídos de https://www.compraonline.bonpreuesclat.cat/categories/celler/5aebd367-ae51-4a42-a2f2-74662454e411?sortBy=favorite
# 🧮 295 productos extraídos de https://www.compraonline.bonpreuesclat.cat/categories/prepara-t-pel-fred/347a3efd-d9ac-4708-a53e-0a5498b7e968?sortBy=favorite
# ✅ Cookies aceptadas
# 🧮 2174 productos extraídos de https://www.compraonline.bonpreuesclat.cat/categories/ofertes/5de4976b-9569-4f39-b265-849da8f25975?sortBy=favorite
# ✅ Cookies aceptadas
# 🧮 269 productos extraídos de https://www.compraonline.bonpreuesclat.cat/categories/novetats/2068f9ba-b1af-4cf1-ad2b-3301c8d1a977?sortBy=favorite

# %%
df_bonpreu["store"] = "Esclat"
df_bonpreu["ppu_num"] = df_bonpreu["price_per_unit_text"].apply(_ppu_simple)

# %%
df_up2 = pd.DataFrame({
    "title": df_bonpreu["name"].astype(str).str.strip(),
    "price_unit": pd.to_numeric(df_bonpreu["price"], errors="coerce").fillna(0.0).astype(float).round(4),
    "price_kg": pd.to_numeric(df_bonpreu.get("ppu_num", df_bonpreu["price"]), errors="coerce"),
    "image": df_bonpreu.get("img_url", "").fillna("").astype(str),
    "store": "Esclat",
})
df_up2["price_kg"] = df_up2["price_kg"].fillna(df_up2["price_unit"]).astype(float).round(4)
df_up2 = df_up2.drop_duplicates(subset=["title","store"], keep="first")

# 👉 añade Esclat sin borrar lo de Mercadona
df_up2.to_sql("producto", engine, if_exists="append", index=False)
print(f"OK: {len(df_up2)} filas añadidas en {DB_PATH} para store='Esclat'")
# Out:
# OK: 18317 filas añadidas en baratazo.db para store='Esclat'

# %% [markdown]
# ### CONSUM

# %%
df_consum = scrape_consum(headless=True)
df_consum["name"] = df_consum["brand"]+" "+df_consum["name"]
# Out:
# 📂 Categorías detectadas: 13
#
# ---- [1/13] https://tienda.consum.es/es/c/bazar/1486?orderById=5&page=1 ----
# 📄 Páginas detectadas: 10
# ↕️ Ronda 1: DOM=40
# ✅ Página 1/10: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 2/10: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 3/10: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 4/10: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 5/10: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 6/10: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 7/10: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 8/10: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 9/10: DOM=40
# ↕️ Ronda 1: DOM=8
# ✅ Página 10/10: DOM=8
# 🧺 184 productos
#
# ---- [2/13] https://tienda.consum.es/es/c/bebidas/1690?orderById=5&page=1 ----
# 📄 Páginas detectadas: 53
# ↕️ Ronda 1: DOM=40
# ✅ Página 1/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 2/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 3/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 4/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 5/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 6/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 7/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 8/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 9/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 10/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 11/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 12/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 13/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 14/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 15/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 16/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 17/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 18/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 19/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 20/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 21/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 22/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 23/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 24/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 25/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 26/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 27/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 28/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 29/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 30/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 31/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 32/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 33/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 34/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 35/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 36/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 37/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 38/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 39/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 40/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 41/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 42/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 43/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 44/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 45/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 46/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 47/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 48/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 49/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 50/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 51/53: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 52/53: DOM=40
# ↕️ Ronda 1: DOM=4
# ✅ Página 53/53: DOM=4
# 🧺 1042 productos
#
# ---- [3/13] https://tienda.consum.es/es/c/congelados/1783?orderById=5&page=1 ----
# 📄 Páginas detectadas: 20
# ↕️ Ronda 1: DOM=40
# ✅ Página 1/20: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 2/20: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 3/20: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 4/20: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 5/20: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 6/20: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 7/20: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 8/20: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 9/20: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 10/20: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 11/20: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 12/20: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 13/20: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 14/20: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 15/20: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 16/20: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 17/20: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 18/20: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 19/20: DOM=40
# ↕️ Ronda 1: DOM=26
# ✅ Página 20/20: DOM=26
# 🧺 391 productos
#
# ---- [4/13] https://tienda.consum.es/es/c/cuidado/2814?orderById=5&page=1 ----
# 📄 Páginas detectadas: 93
# ↕️ Ronda 1: DOM=40
# ✅ Página 1/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 2/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 3/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 4/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 5/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 6/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 7/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 8/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 9/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 10/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 11/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 12/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 13/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 14/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 15/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 16/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 17/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 18/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 19/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 20/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 21/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 22/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 23/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 24/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 25/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 26/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 27/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 28/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 29/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 30/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 31/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 32/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 33/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 34/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 35/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 36/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 37/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 38/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 39/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 40/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 41/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 42/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 43/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 44/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 45/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 46/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 47/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 48/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 49/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 50/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 51/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 52/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 53/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 54/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 55/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 56/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 57/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 58/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 59/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 60/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 61/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 62/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 63/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 64/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 65/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 66/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 67/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 68/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 69/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 70/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 71/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 72/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 73/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 74/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 75/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 76/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 77/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 78/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 79/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 80/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 81/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 82/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 83/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 84/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 85/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 86/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 87/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 88/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 89/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 90/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 91/93: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 92/93: DOM=40
# ↕️ Ronda 1: DOM=18
# ✅ Página 93/93: DOM=18
# 🧺 1849 productos
#
# ---- [5/13] https://tienda.consum.es/es/c/despensa/2811?orderById=5&page=1 ----
# 📄 Páginas detectadas: 162
# ↕️ Ronda 1: DOM=40
# ✅ Página 1/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 2/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 3/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 4/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 5/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 6/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 7/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 8/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 9/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 10/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 11/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 12/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 13/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 14/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 15/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 16/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 17/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 18/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 19/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 20/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 21/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 22/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 23/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 24/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 25/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 26/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 27/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 28/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 29/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 30/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 31/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 32/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 33/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 34/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 35/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 36/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 37/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 38/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 39/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 40/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 41/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 42/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 43/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 44/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 45/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 46/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 47/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 48/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 49/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 50/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 51/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 52/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 53/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 54/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 55/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 56/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 57/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 58/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 59/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 60/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 61/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 62/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 63/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 64/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 65/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 66/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 67/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 68/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 69/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 70/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 71/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 72/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 73/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 74/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 75/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 76/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 77/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 78/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 79/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 80/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 81/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 82/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 83/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 84/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 85/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 86/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 87/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 88/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 89/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 90/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 91/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 92/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 93/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 94/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 95/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 96/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 97/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 98/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 99/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 100/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 101/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 102/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 103/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 104/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 105/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 106/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 107/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 108/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 109/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 110/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 111/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 112/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 113/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 114/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 115/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 116/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 117/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 118/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 119/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 120/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 121/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 122/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 123/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 124/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 125/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 126/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 127/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 128/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 129/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 130/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 131/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 132/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 133/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 134/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 135/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 136/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 137/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 138/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 139/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 140/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 141/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 142/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 143/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 144/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 145/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 146/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 147/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 148/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 149/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 150/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 151/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 152/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 153/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 154/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 155/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 156/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 157/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 158/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 159/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 160/162: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 161/162: DOM=40
# ↕️ Ronda 1: DOM=16
# ✅ Página 162/162: DOM=16
# 🧺 3226 productos
#
# ---- [6/13] https://tienda.consum.es/es/c/drogueria/1239?orderById=5&page=1 ----
# ➡️ Detectada página 2
# ➡️ Detectada página 3
# ➡️ Detectada página 4
# ➡️ Detectada página 5
# ➡️ Detectada página 6
# ➡️ Detectada página 7
# ➡️ Detectada página 8
# ➡️ Detectada página 9
# ➡️ Detectada página 10
# ➡️ Detectada página 11
# ➡️ Detectada página 12
# ➡️ Detectada página 13
# ➡️ Detectada página 14
# ➡️ Detectada página 15
# ➡️ Detectada página 16
# ➡️ Detectada página 17
# ➡️ Detectada página 18
# ➡️ Detectada página 19
# ➡️ Detectada página 20
# ➡️ Detectada página 21
# ➡️ Detectada página 22
# ➡️ Detectada página 23
# ➡️ Detectada página 24
# ➡️ Detectada página 25
# ➡️ Detectada página 26
# ➡️ Detectada página 27
# ➡️ Detectada página 28
# ➡️ Detectada página 29
# ➡️ Detectada página 30
# ➡️ Detectada página 31
# ➡️ Detectada página 32
# ➡️ Detectada página 33
# ➡️ Detectada página 34
# ➡️ Detectada página 35
# ➡️ Detectada página 36
# ➡️ Detectada página 37
# ➡️ Detectada página 38
# 📄 Páginas detectadas: 38
# ↕️ Ronda 1: DOM=40
# ✅ Página 1/38: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 2/38: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 3/38: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 4/38: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 5/38: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 6/38: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 7/38: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 8/38: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 9/38: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 10/38: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 11/38: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 12/38: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 13/38: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 14/38: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 15/38: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 16/38: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 17/38: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 18/38: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 19/38: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 20/38: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 21/38: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 22/38: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 23/38: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 24/38: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 25/38: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 26/38: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 27/38: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 28/38: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 29/38: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 30/38: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 31/38: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 32/38: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 33/38: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 34/38: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 35/38: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 36/38: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 37/38: DOM=40
# ↕️ Ronda 1: DOM=36
# ✅ Página 38/38: DOM=36
# 🧺 758 productos
#
# ---- [7/13] https://tienda.consum.es/es/c/ecologico-saludable/5281?orderById=5&page=1 ----
# 📄 Páginas detectadas: 8
# ↕️ Ronda 1: DOM=40
# ✅ Página 1/8: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 2/8: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 3/8: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 4/8: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 5/8: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 6/8: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 7/8: DOM=40
# ↕️ Ronda 1: DOM=26
# ✅ Página 8/8: DOM=26
# 🧺 153 productos
#
# ---- [8/13] https://tienda.consum.es/es/c/frescos/2812?orderById=5&page=1 ----
# 📄 Páginas detectadas: 61
# ↕️ Ronda 1: DOM=40
# ✅ Página 1/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 2/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 3/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 4/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 5/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 6/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 7/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 8/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 9/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 10/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 11/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 12/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 13/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 14/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 15/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 16/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 17/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 18/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 19/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 20/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 21/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 22/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 23/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 24/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 25/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 26/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 27/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 28/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 29/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 30/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 31/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 32/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 33/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 34/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 35/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 36/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 37/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 38/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 39/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 40/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 41/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 42/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 43/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 44/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 45/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 46/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 47/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 48/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 49/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 50/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 51/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 52/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 53/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 54/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 55/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 56/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 57/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 58/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 59/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 60/61: DOM=40
# ↕️ Ronda 1: DOM=24
# ✅ Página 61/61: DOM=24
# 🧺 1212 productos
#
# ---- [9/13] https://tienda.consum.es/es/c/horno/4108?orderById=5&page=1 ----
# 📄 Páginas detectadas: 8
# ↕️ Ronda 1: DOM=40
# ✅ Página 1/8: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 2/8: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 3/8: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 4/8: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 5/8: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 6/8: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 7/8: DOM=40
# ↕️ Ronda 1: DOM=28
# ✅ Página 8/8: DOM=28
# 🧺 154 productos
#
# ---- [10/13] https://tienda.consum.es/es/c/infantil/2297?orderById=5&page=1 ----
# 📄 Páginas detectadas: 12
# ↕️ Ronda 1: DOM=40
# ✅ Página 1/12: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 2/12: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 3/12: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 4/12: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 5/12: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 6/12: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 7/12: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 8/12: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 9/12: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 10/12: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 11/12: DOM=40
# ↕️ Ronda 1: DOM=6
# ✅ Página 12/12: DOM=6
# 🧺 223 productos
#
# ---- [11/13] https://tienda.consum.es/es/c/mascotas/2469?orderById=5&page=1 ----
# 📄 Páginas detectadas: 9
# ↕️ Ronda 1: DOM=40
# ✅ Página 1/9: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 2/9: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 3/9: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 4/9: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 5/9: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 6/9: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 7/9: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 8/9: DOM=40
# ↕️ Ronda 1: DOM=34
# ✅ Página 9/9: DOM=34
# 🧺 177 productos
#
# ---- [12/13] https://tienda.consum.es/es/c/ofertas-supermercado/99999?orderById=5&page=1 ----
# 📄 Páginas detectadas: 61
# ↕️ Ronda 1: DOM=40
# ✅ Página 1/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 2/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 3/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 4/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 5/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 6/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 7/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 8/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 9/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 10/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 11/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 12/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 13/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 14/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 15/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 16/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 17/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 18/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 19/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 20/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 21/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 22/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 23/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 24/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 25/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 26/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 27/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 28/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 29/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 30/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 31/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 32/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 33/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 34/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 35/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 36/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 37/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 38/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 39/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 40/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 41/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 42/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 43/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 44/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 45/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 46/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 47/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 48/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 49/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 50/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 51/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 52/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 53/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 54/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 55/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 56/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 57/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 58/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 59/61: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 60/61: DOM=40
# ↕️ Ronda 1: DOM=36
# ✅ Página 61/61: DOM=36
# 🧺 1218 productos
#
# ---- [13/13] https://tienda.consum.es/es/c/platos-preparados/1833?orderById=5&page=1 ----
# 📄 Páginas detectadas: 13
# ↕️ Ronda 1: DOM=40
# ✅ Página 1/13: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 2/13: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 3/13: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 4/13: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 5/13: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 6/13: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 7/13: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 8/13: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 9/13: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 10/13: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 11/13: DOM=40
# ↕️ Ronda 1: DOM=40
# ✅ Página 12/13: DOM=40
# ↕️ Ronda 1: DOM=28
# ✅ Página 13/13: DOM=28
# 🧺 254 productos

# %%
df_up_consum = pd.DataFrame({
    "title": df_consum["name"].astype(str).str.strip(),
    "price_unit": pd.to_numeric(df_consum["price"], errors="coerce").fillna(0.0).astype(float).round(4),
    "image": df_consum.get("image", "").fillna("").astype(str),
    "store": "Consum",
})

ppu_series = df_consum.get("ppu_text", pd.Series([""] * len(df_consum)))
df_up_consum["price_kg"] = [
    round(_ppu_to_base(ppu, fallback_unit_price=pu), 4)
    for ppu, pu in zip(ppu_series.fillna(""), df_up_consum["price_unit"])
]
df_up_consum["price_kg"] = df_up_consum["price_kg"].fillna(df_up_consum["price_unit"]).astype(float).round(4)
df_up_consum = df_up_consum.drop_duplicates(subset=["title","store"], keep="first")

# 👉 añade Consum sin borrar lo de Mercadona
df_up_consum.to_sql("producto", engine, if_exists="append", index=False)
print(f"OK: {len(df_up_consum)} filas añadidas en {DB_PATH} para store='Consum'")
# Out:
# OK: 8942 filas añadidas en baratazo.db para store='Consum'

# %% [markdown]
# ### TEST SQL

# %%
def eur_es(x: float) -> str:
    if pd.isna(x):
        return ""
    s = f"{x:,.2f}"
    return s.replace(",", "X").replace(".", ",").replace("X", ".") + " €"

with engine.connect() as conn:
    q = text("""
        SELECT title, store, price_unit, price_kg, image
        FROM producto
        WHERE
          (
            LOWER(REPLACE(REPLACE(REPLACE(REPLACE(REPLACE(REPLACE(title,
              'á','a'),'é','e'),'í','i'),'ó','o'),'ú','u'),'ü','u')) LIKE '%kiwi%'
            OR
            LOWER(REPLACE(REPLACE(REPLACE(REPLACE(REPLACE(REPLACE(title,
              'á','a'),'é','e'),'í','i'),'ó','o'),'ú','u'),'ü','u')) LIKE '%kivi%'
          )
          AND price_kg IS NOT NULL
        ORDER BY price_kg ASC;
    """)
    df_pescado = pd.read_sql(q, conn)

view = df_pescado.copy()
view["Precio unidad"] = view["price_unit"].map(eur_es)
view["Precio kg/L"]   = view["price_kg"].map(eur_es)
view = view[["store", "title", "Precio unidad", "Precio kg/L", "image"]]
view.rename(columns={"store": "Tienda", "title": "Producto"}, inplace=True)
view.index = range(1, len(view) + 1)

pd.set_option("display.max_colwidth", 80)
print(f"🐟 Encontrados: {len(view)} productos (ordenados por kg/L más barato)")
print(view.to_string())
# Out:
# 🐟 Encontrados: 18 productos (ordenados por kg/L más barato)
#        Tienda                                                                                       Producto Precio unidad Precio kg/L                                                                                                                                       image
# 1      Esclat                                                                                 Kiwi verd 1 u.        0,59 €      0,59 €  https://www.compraonline.bonpreuesclat.cat/images-v3/dcbcfd72-cf23-44a2-8e14-8a38edd645a3/4fd8664c-1bbb-4dc9-a6aa-4185feeaa33c/300x300.jpg
# 2      Esclat                                                                   ZESPRI Kiwi groc Zespri 1 u.        0,99 €      0,99 €  https://www.compraonline.bonpreuesclat.cat/images-v3/dcbcfd72-cf23-44a2-8e14-8a38edd645a3/6943d8e5-5ac3-4689-9c90-c710cee6b00b/300x300.jpg
# 3      Consum                                             TESORO NATUR Refresco Kiwi con Chía Botella 0,45 L        1,55 €      3,44 €                          https://cdn-consum.aktiosdigitalservices.com/tol/consum/media/product/img/300x300/7395726_001.jpg?t=20241220170001
# 4   Mercadona                                                                        Kiwis verdes1 kg aprox.        4,25 €      4,25 €                                           https://prod-mercadona.imgix.net/images/e887a535440a80f19a036df7d70f124a.jpg?fit=crop&h=300&w=300
# 5      Consum                                                FRUTAE Smoothie Kiwi, Piña con Spirulina 250 ml        1,09 €      4,36 €                          https://cdn-consum.aktiosdigitalservices.com/tol/consum/media/product/img/300x300/7377927_001.jpg?t=20210615140602
# 6   Mercadona                                                                   Kiwi verdePieza 109 g aprox.        0,50 €      4,59 €                                           https://prod-mercadona.imgix.net/images/49e3e74a455daf4169248dfb52ae9a6d.jpg?fit=crop&h=300&w=300
# 7      Consum                                   DANONE Activia 00% con Kiwi Bífidus Desnatado P-4 4 x 120 Gr        2,39 €      4,98 €                          https://cdn-consum.aktiosdigitalservices.com/tol/consum/media/product/img/300x300/7010598_001.jpg?t=20240418040002
# 8   Mercadona                                               Mermelada de ciruela y kiwi HacendadoTarro 340 g        1,70 €      5,00 €                                           https://prod-mercadona.imgix.net/images/709726b054a6427b34435b6e1c9a132b.jpg?fit=crop&h=300&w=300
# 9      Esclat                                                                        ACTIVIA Iogurt amb kiwi        2,99 €      6,23 €  https://www.compraonline.bonpreuesclat.cat/images-v3/dcbcfd72-cf23-44a2-8e14-8a38edd645a3/00018d08-2eb9-4de3-81dc-f9cbc9870ade/300x300.jpg
# 10     Consum                                                   HELIOS Mermelada Ciruela y Kiwi Tarro 340 Gr        2,20 €      6,47 €                          https://cdn-consum.aktiosdigitalservices.com/tol/consum/media/product/img/300x300/7468080_001.jpg?t=20251014091502
# 11  Mercadona                                                                    Kiwis amarillos500 g aprox.        3,25 €      6,50 €                                           https://prod-mercadona.imgix.net/images/c68209d5df52ad0af0087511c706c56b.jpg?fit=crop&h=300&w=300
# 12     Esclat                                                                          ZESPRI Kiwi groc 1 u.        0,98 €      6,99 €  https://www.compraonline.bonpreuesclat.cat/images-v3/dcbcfd72-cf23-44a2-8e14-8a38edd645a3/4c0c1ea8-b467-49aa-8cd0-1158453b0b42/300x300.jpg
# 13     Consum                                                                           ZESPRI Kiwi Amarillo        1,01 €      6,99 €                          https://cdn-consum.aktiosdigitalservices.com/tol/consum/media/product/img/300x300/7105240_001.jpg?t=20220601040002
# 14     Esclat                                                            ZESPRI Kiwi verd en safata de 500 g        3,79 €      7,58 €  https://www.compraonline.bonpreuesclat.cat/images-v3/dcbcfd72-cf23-44a2-8e14-8a38edd645a3/0b71c03d-fbc9-431a-9636-612a6bded370/300x300.jpg
# 15     Esclat                                                            ZESPRI Kiwi groc en safata de 500 g        3,99 €      7,98 €  https://www.compraonline.bonpreuesclat.cat/images-v3/dcbcfd72-cf23-44a2-8e14-8a38edd645a3/c509ae6c-4c1c-43a3-973e-c2909b2986bd/300x300.jpg
# 16     Esclat                                                        ZESPRI Kiwi ecològic en safata de 500 g        4,29 €      8,58 €  https://www.compraonline.bonpreuesclat.cat/images-v3/dcbcfd72-cf23-44a2-8e14-8a38edd645a3/0c80a0eb-0b60-4864-b905-3faa9941e27d/300x300.jpg
# 17  Mercadona  Bífidus desnatado probiótico con kiwi Hacendado 0% m.g. 0% sin azúcares añadidos4 ud. x 125 g        1,30 €     10,40 €                                           https://prod-mercadona.imgix.net/images/4e90bb7359c16ff856f2b933368e9228.jpg?fit=crop&h=300&w=300
# 18     Consum                                          JUST LOADING Energy Gels Fresa y Kiwi Pack de 3 90 Gr        2,05 €     22,78 €                          https://cdn-consum.aktiosdigitalservices.com/tol/consum/media/product/img/300x300/7349082_001.jpg?t=20250204091502

# %%
df_up1 = pd.DataFrame({
    "title": df["name"].astype(str).str.strip(),
    "price_unit": pd.to_numeric(df["price"], errors="coerce").fillna(0.0).astype(float).round(4),
    "price_kg": pd.to_numeric(df["price_per_kg_or_l"], errors="coerce"),
    "image": df.get("img_url", "").fillna("").astype(str),
    "store": "Mercadona",
})
df_up1["price_kg"] = df_up1["price_kg"].fillna(df_up1["price_unit"]).astype(float).round(4)
df_up1 = df_up1.drop_duplicates(subset=["title","store"], keep="first")


# 👉 crea/arranca la tabla con Mercadona (replace) y deja lista para añadir Esclat
df_up1.to_sql("producto", engine, if_exists="append", index=False)
print(f"OK: {len(df_up1)} filas cargadas en {DB_PATH} para store='Mercadona'")
# Out:
# OK: 4375 filas cargadas en baratazo.db para store='Mercadona'

# %%
#with engine.begin() as conn: conn.exec_driver_sql("DELETE FROM producto")
